# %%
import pickle
import numpy as np
from matplotlib import pyplot as plt

# deets format:
# First digit: adversary blindness.  0: can see everything; 1: can't see prey; 2: can't see anything
# Second digit: comm setting.  0: no comms; 1: prey can listen; 2: only adversaries comm.
# Third digit: number of prey
# Fouth digit: number of adversaries
# Fifth digit (optional): number of available comms, default 4 (A, B, C, D)

all_the_deets = ['0-2-1-4', '2-2-2-4', '1-2-1-4', '1-2-1-4-8', '1-2-2-4', '1-2-2-4-8', '0-0-1-4',
                 '1-1-1-4', '1-0-1-4', '0-1-1-4', '1-2-1-4-2', '0-2-1-4-8', '0-2-2-4', '0-0-2-4',
                 '2-0-1-4', '2-1-1-4', '2-2-1-4-8', '0-2-2-4-8', '2-1-1-4-8', '1-1-1-4-8', '0-1-1-4-8', '1-2-1-3']

def open_pickle(deets):
    with open('./learning_curves/commplex_tag-'+deets+'-baseline_agrewards.pkl', 'rb') as f:
        data = pickle.load(f)
    return np.array(data)

def get_rewards(deets):
    all_rewards = open_pickle(deets)
    num_adversaries = int(deets.split('-')[3])
    rewards = np.average(all_rewards[:, :num_adversaries], axis=1)
    return rewards

def get_prey_rewards(deets):
    all_rewards = open_pickle(deets)
    num_adversaries = int(deets.split('-')[3])
    rewards = np.average(all_rewards[:, num_adversaries:], axis=1)
    return rewards

def make_comparison(deets_list, labels=None, prey=False):
    rewards_list = [get_rewards(deets) for deets in deets_list]
    if labels is None:
        labels = deets_list
        
    fig = plt.figure()
    ax = fig.add_subplot(111)
    for i in range(len(deets_list)):
        ax.plot(rewards_list[i], label=labels[i])
    ax.legend()
    ax.set_xlabel('# 1000s of episodes')
    ax.set_ylabel('average predator reward')
    ax.set_title('Influence of comms and vision on predator pack performance\n(4 predators, 1 prey, 4 comm channels)')
    plt.show()

# %%
make_comparison(['0-2-1-4', '0-0-1-4', '1-2-1-4', '1-0-1-4'], ['comms, full vision', 'no comms, full vision', 'comms, partial vision', 'no comms, partial vision'])

# %%
make_comparison(['0-2-1-4', '0-0-1-4', '2-2-1-4', '2-0-1-4'], ['comms, full vision', 'no comms, full vision', 'comms, no vision', 'no comms, no vision'])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-35-936ce69813d2> in <module>
# ----> 1 make_comparison(['0-2-1-4', '0-0-1-4', '2-2-1-4', '2-0-1-4'], ['comms, full vision', 'no comms, full vision', 'comms, no vision', 'no comms, no vision'])
#
# <ipython-input-33-d74389154714> in make_comparison(deets_list, labels)
#      32
#      33 def make_comparison(deets_list, labels=None):
# ---> 34     rewards_list = [get_rewards(deets) for deets in deets_list]
#      35     if labels is None:
#      36         labels = deets_list
#
# <ipython-input-33-d74389154714> in <listcomp>(.0)
#      32
#      33 def make_comparison(deets_list, labels=None):
# ---> 34     rewards_list = [get_rewards(deets) for deets in deets_list]
#      35     if labels is None:
#      36         labels = deets_list
#
# <ipython-input-33-d74389154714> in get_rewards(deets)
#      22     all_rewards = open_pickle(deets)
#      23     num_adversaries = int(deets.split('-')[3])
# ---> 24     rewards = np.average(all_rewards[:, :num_adversaries], axis=1)
#      25     return rewards
#      26
#
# IndexError: too many indices for array
